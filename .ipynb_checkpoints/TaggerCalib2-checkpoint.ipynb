# %% [markdown]
# # A (Possible) Code for Calibrating the Tagger Timing

# %% [markdown]
# First, we import the tools we'll need:

# %%
import Acqu as aq
import AcquDetector as aqdet
import ROOT
import numpy as np
import json
from collections import OrderedDict
from rootpy.plotting import histogram, Hist2D, Hist, Canvas

# %% [markdown]
# Import the data to be analyzed:

# %%
inFile = '/scratch/2019-05_Timepix/Timepix_33.dat'
aq.openFile(inFile)
# Out:
# Mk2 Data

# %% [markdown]
# Load in the detector file for the Tagger:

# %%
aqdet.LoadDetectors(['taggerNewer.json'])
# Out:
# taggerNewer.json

# %% [markdown]
# We set up histograms for each of the channels, and then fill them with tagger times from our data:

# %%
taggerChannels = aqdet.Channels['Tagger']     # number of channels in the tagger (368)

histos = [None]*taggerChannels                # set up an array of 368 histograms to fill      

for i in range(taggerChannels):               # for each tagger channel
    histos[i] = Hist(1300,-500,800)           # set up a histogram for that tagger channel

def plotCalTagger():
    data = aqdet.Calibrate(aq.adcArray)              # calibrate the data
    taggerTimes = aqdet.Arrays['Tagger']['Time']     # get the tagger times
    
    for dat in taggerTimes:                          # for each data point
        for time in dat['Time']:                     # for each tagger time
            for i in range(taggerChannels):          # for each channel
                if (dat['channel']==i):              # if the channel of that data point is the current channel
                    histos[i].Fill(time)             # then put that time in the histogram
                    
    if(aq.eventNo%5000==0):                          # print a processing statement every 5000 events
        print("Events Processed: ",aq.eventNo)
    
aq.runFunction(plotCalTagger,0,1000000)               # run this process over 500000 events
# Out:
# ('Events Processed: ', 5000)
# ('Events Processed: ', 10000)
# ('Events Processed: ', 15000)
# ('Events Processed: ', 20000)
# ('Events Processed: ', 25000)
# ('Events Processed: ', 30000)
# ('Events Processed: ', 35000)
# ('Events Processed: ', 40000)
# ('Events Processed: ', 45000)
# ('Events Processed: ', 50000)
# ('Events Processed: ', 55000)
# ('Events Processed: ', 60000)
# ('Events Processed: ', 65000)
# ('Events Processed: ', 70000)
# ('Events Processed: ', 75000)
# ('Events Processed: ', 80000)
# ('Events Processed: ', 85000)
# ('Events Processed: ', 90000)
# ('Events Processed: ', 95000)
# ('Events Processed: ', 100000)
# ('Events Processed: ', 105000)
# ('Events Processed: ', 110000)
# ('Events Processed: ', 115000)
# ('Events Processed: ', 120000)
# ('Events Processed: ', 125000)
# ('Events Processed: ', 130000)
# ('Events Processed: ', 135000)
# ('Events Processed: ', 140000)
# ('Events Processed: ', 145000)
# ('Events Processed: ', 150000)
# ('Events Processed: ', 155000)
# ('Events Processed: ', 160000)
# ('Events Processed: ', 165000)
# ('Events Processed: ', 170000)
# ('Events Processed: ', 175000)
# ('Events Processed: ', 180000)
# ('Events Processed: ', 185000)
# ('Events Processed: ', 190000)
# ('Events Processed: ', 195000)
# ('Events Processed: ', 200000)
# ('Events Processed: ', 205000)
# ('Events Processed: ', 210000)
# ('Events Processed: ', 215000)
# ('Events Processed: ', 220000)
# ('Events Processed: ', 225000)
# ('Events Processed: ', 230000)
# ('Events Processed: ', 235000)
# ('Events Processed: ', 240000)
# ('Events Processed: ', 245000)
# ('Events Processed: ', 250000)
# ('Events Processed: ', 255000)
# ('Events Processed: ', 260000)
# ('Events Processed: ', 265000)
# ('Events Processed: ', 270000)
# ('Events Processed: ', 275000)
# ('Events Processed: ', 280000)
# ('Events Processed: ', 285000)
# ('Events Processed: ', 290000)
# ('Events Processed: ', 295000)
# ('Events Processed: ', 300000)
# ('Events Processed: ', 305000)
# ('Events Processed: ', 310000)
# ('Events Processed: ', 315000)
# ('Events Processed: ', 320000)
# ('Events Processed: ', 325000)
# ('Events Processed: ', 330000)
# ('Events Processed: ', 335000)
# ('Events Processed: ', 340000)
# ('Events Processed: ', 345000)
# ('Events Processed: ', 350000)
# ('Events Processed: ', 355000)
# ('Events Processed: ', 360000)
# ('Events Processed: ', 365000)
# ('Events Processed: ', 370000)
# ('Events Processed: ', 375000)
# ('Events Processed: ', 380000)
# ('Events Processed: ', 385000)
# ('Events Processed: ', 390000)
# ('Events Processed: ', 395000)
# ('Events Processed: ', 400000)
# ('Events Processed: ', 405000)
# ('Events Processed: ', 410000)
# ('Events Processed: ', 415000)
# ('Events Processed: ', 420000)
# ('Events Processed: ', 425000)
# ('Events Processed: ', 430000)
# ('Events Processed: ', 435000)
# ('Events Processed: ', 440000)
# ('Events Processed: ', 445000)
# ('Events Processed: ', 450000)
# ('Events Processed: ', 455000)
# ('Events Processed: ', 460000)
# ('Events Processed: ', 465000)
# ('Events Processed: ', 470000)
# ('Events Processed: ', 475000)
# ('Events Processed: ', 480000)
# ('Events Processed: ', 485000)
# ('Events Processed: ', 490000)
# ('Events Processed: ', 495000)
# ('Events Processed: ', 500000)
# ('Events Processed: ', 505000)
# ('Events Processed: ', 510000)
# ('Events Processed: ', 515000)
# ('Events Processed: ', 520000)
# ('Events Processed: ', 525000)
# ('Events Processed: ', 530000)
# ('Events Processed: ', 535000)
# ('Events Processed: ', 540000)
# ('Events Processed: ', 545000)
# ('Events Processed: ', 550000)
# ('Events Processed: ', 555000)
# ('Events Processed: ', 560000)
# ('Events Processed: ', 565000)
# ('Events Processed: ', 570000)
# ('Events Processed: ', 575000)
# ('Events Processed: ', 580000)
# ('Events Processed: ', 585000)
# ('Events Processed: ', 590000)
# ('Events Processed: ', 595000)
# ('Events Processed: ', 600000)
# ('Events Processed: ', 605000)
# ('Events Processed: ', 610000)
# ('Events Processed: ', 615000)
# ('Events Processed: ', 620000)
# ('Events Processed: ', 625000)
# ('Events Processed: ', 630000)
# ('Events Processed: ', 635000)
# ('Events Processed: ', 640000)
# ('Events Processed: ', 645000)
# ('Events Processed: ', 650000)
# ('Events Processed: ', 655000)
# ('Events Processed: ', 660000)
# ('Events Processed: ', 665000)
# ('Events Processed: ', 670000)
# ('Events Processed: ', 675000)
# ('Events Processed: ', 680000)
# ('Events Processed: ', 685000)
# ('Events Processed: ', 690000)
# ('Events Processed: ', 695000)
# ('Events Processed: ', 700000)
# ('Events Processed: ', 705000)
# ('Events Processed: ', 710000)
# ('Events Processed: ', 715000)
# ('Events Processed: ', 720000)
# ('Events Processed: ', 725000)
# ('Events Processed: ', 730000)
# ('Events Processed: ', 735000)
# ('Events Processed: ', 740000)
# ('Events Processed: ', 745000)
# ('Events Processed: ', 750000)
# ('Events Processed: ', 755000)
# ('Events Processed: ', 760000)
# ('Events Processed: ', 765000)
# ('Events Processed: ', 770000)
# ('Events Processed: ', 775000)
# ('Events Processed: ', 780000)
# ('Events Processed: ', 785000)
# ('Events Processed: ', 790000)
# ('Events Processed: ', 795000)
# ('Events Processed: ', 800000)
# ('Events Processed: ', 805000)
# ('Events Processed: ', 810000)
# ('Events Processed: ', 815000)
# ('Events Processed: ', 820000)
# ('Events Processed: ', 825000)
# ('Events Processed: ', 830000)
# ('Events Processed: ', 835000)
# ('Events Processed: ', 840000)
# ('Events Processed: ', 845000)
# ('Events Processed: ', 850000)
# ('Events Processed: ', 855000)
# ('Events Processed: ', 860000)
# ('Events Processed: ', 865000)
# ('Events Processed: ', 870000)
# ('Events Processed: ', 875000)
# ('Events Processed: ', 880000)
# ('Events Processed: ', 885000)
# ('Events Processed: ', 890000)
# ('Events Processed: ', 895000)
# ('Events Processed: ', 900000)
# ('Events Processed: ', 905000)
# ('Events Processed: ', 910000)
# ('Events Processed: ', 915000)
# ('Events Processed: ', 920000)
# ('Events Processed: ', 925000)
# ('Events Processed: ', 930000)
# ('Events Processed: ', 935000)
# ('Events Processed: ', 940000)
# ('Events Processed: ', 945000)
# ('Events Processed: ', 950000)
# ('Events Processed: ', 955000)
# ('Events Processed: ', 960000)
# ('Events Processed: ', 965000)
# ('Events Processed: ', 970000)
# ('Events Processed: ', 975000)
# ('Events Processed: ', 980000)
# ('Events Processed: ', 985000)
# ('Events Processed: ', 990000)
# ('Events Processed: ', 995000)
# ('Events Processed: ', 1000000)

# %% [markdown]
# Now we plot the data for the tagger channels and apply a gaussian fit (with an offset) to them:

# %%
ROOT.enableJSVis()

tagger_times = ROOT.TFile("tagger_times.root","RECREATE")     # create a root file to put all the histograms into

myFit = ROOT.TF1("myFit","gaus(0)+pol0(3)")                   # make a gaussian fit with an offset/background
myFit.SetParNames("constant","mean","stdev","background")     # label the parameters

peak = [None]*taggerChannels          # set up an array for the peak locations
sigma = [None]*taggerChannels         # set up an array for the standard deviations of the peaks
bgLevel = [None]*taggerChannels       # set up an array for the background levels

pk = 140     # initialize a peak value to try
sig = 1.1    # initialize a standard deviation value to try
bg = 100     # initialize a background value to try

for i in range(taggerChannels):                                        
    myFit.SetParameter(1,pk)                 
    myFit.SetParameter(2,sig)                
    myFit.SetParameter(3,bg)                
    
    histos[i].SetTitle("Channel "+str(i))      
    histos[i].Draw()                
    
    if(histos[i].GetEntries()>10):                                     
        histos[i].Fit('myFit','SQ','',-300,600)                           
        peak[i] = histos[i].Fit('myFit','SQ','',-300,600).Get().Parameter(1)
        sigma[i] = histos[i].Fit('myFit','SQ','',-300,600).Get().Parameter(2)
        bgLevel[i] = histos[i].Fit('myFit','SQ','',-300,600).Get().Parameter(3) 
        
        k=1
        while(ROOT.gMinuit.fCstatu!="CONVERGED " or peak[i] > 160 or peak[i] < 120 or sigma[i]<-2 or sigma[i]>4):                                     
            myFit.SetParameter(1,140-k)                 
            myFit.SetParameter(2,1)                   
            myFit.SetParameter(3,80-k)
            
            peak[i] = histos[i].Fit('myFit','SQ','',-300,600).Get().Parameter(1)
            sigma[i] = histos[i].Fit('myFit','SQ','',-300,600).Get().Parameter(2)
            bgLevel[i] = histos[i].Fit('myFit','SQ','',-300,600).Get().Parameter(3) 
            
            k+=1
            #print("loop",i,k,peak[i],sigma[i],bgLevel[i])
            
       # pk = peak[i]
       # sig = sigma[i]
       # bg = bgLevel[i]
  #      
        if (peak[i]>180 or peak[i]<100):
            print("Check channel "+ str(i)+" for peak")
            print(i,k,pk,sig,bg)
       
        if (sigma[i]<0):
            print("Check channel "+ str(i)+" for sigma")
            print(i,k,pk,sig,bg)
            
   #         
    else:                                            
        print("Histogram "+str(i)+" is empty (has "+str(histos[i].GetEntries())+" entries).")   
     
    histos[i].Write("tagger_times")
# Out:
# Check channel 10 for sigma
# (10, 2, 140, 1.1, 100)
# Check channel 20 for sigma
# (20, 3, 140, 1.1, 100)
# Check channel 74 for sigma
# (74, 1, 140, 1.1, 100)
# Check channel 76 for sigma
# (76, 1, 140, 1.1, 100)
# Check channel 77 for sigma
# (77, 1, 140, 1.1, 100)
# Check channel 78 for sigma
# (78, 1, 140, 1.1, 100)
# Check channel 79 for sigma
# (79, 1, 140, 1.1, 100)
# Check channel 85 for sigma
# (85, 1, 140, 1.1, 100)
# Check channel 96 for sigma
# (96, 1, 140, 1.1, 100)
# Check channel 98 for sigma
# (98, 1, 140, 1.1, 100)
# Check channel 100 for sigma
# (100, 1, 140, 1.1, 100)
# Check channel 101 for sigma
# (101, 1, 140, 1.1, 100)
# Check channel 103 for sigma
# (103, 1, 140, 1.1, 100)
# Check channel 106 for sigma
# (106, 1, 140, 1.1, 100)
# Check channel 108 for sigma
# (108, 1, 140, 1.1, 100)
# Check channel 109 for sigma
# (109, 1, 140, 1.1, 100)
# Check channel 111 for sigma
# (111, 1, 140, 1.1, 100)
# Check channel 117 for sigma
# (117, 1, 140, 1.1, 100)
# Check channel 118 for sigma
# (118, 1, 140, 1.1, 100)
# Check channel 119 for sigma
# (119, 1, 140, 1.1, 100)
# Check channel 120 for sigma
# (120, 1, 140, 1.1, 100)
# Check channel 124 for sigma
# (124, 2, 140, 1.1, 100)
# Check channel 125 for sigma
# (125, 2, 140, 1.1, 100)
# Check channel 127 for sigma
# (127, 2, 140, 1.1, 100)
# Check channel 129 for sigma
# (129, 1, 140, 1.1, 100)
# Check channel 130 for sigma
# (130, 1, 140, 1.1, 100)
# Check channel 131 for sigma
# (131, 1, 140, 1.1, 100)
# Check channel 132 for sigma
# (132, 1, 140, 1.1, 100)
# Check channel 133 for sigma
# (133, 1, 140, 1.1, 100)
# Check channel 134 for sigma
# (134, 1, 140, 1.1, 100)
# Check channel 135 for sigma
# (135, 1, 140, 1.1, 100)
# Check channel 136 for sigma
# (136, 1, 140, 1.1, 100)
# Check channel 137 for sigma
# (137, 1, 140, 1.1, 100)
# Check channel 138 for sigma
# (138, 1, 140, 1.1, 100)
# Check channel 141 for sigma
# (141, 2, 140, 1.1, 100)
# Check channel 144 for sigma
# (144, 1, 140, 1.1, 100)
# Check channel 146 for sigma
# (146, 1, 140, 1.1, 100)
# Check channel 147 for sigma
# (147, 1, 140, 1.1, 100)
# Check channel 148 for sigma
# (148, 1, 140, 1.1, 100)
# Check channel 149 for sigma
# (149, 3, 140, 1.1, 100)
# Check channel 151 for sigma
# (151, 1, 140, 1.1, 100)
# Check channel 152 for sigma
# (152, 1, 140, 1.1, 100)
# Check channel 153 for sigma
# (153, 2, 140, 1.1, 100)
# Check channel 154 for sigma
# (154, 1, 140, 1.1, 100)
# Check channel 155 for sigma
# (155, 1, 140, 1.1, 100)
# Check channel 158 for sigma
# (158, 1, 140, 1.1, 100)
# Check channel 159 for sigma
# (159, 1, 140, 1.1, 100)
# Check channel 160 for sigma
# (160, 1, 140, 1.1, 100)
# Check channel 163 for sigma
# (163, 1, 140, 1.1, 100)
# Check channel 164 for sigma
# (164, 1, 140, 1.1, 100)
# Check channel 165 for sigma
# (165, 1, 140, 1.1, 100)
# Check channel 167 for sigma
# (167, 1, 140, 1.1, 100)
# Check channel 168 for sigma
# (168, 5, 140, 1.1, 100)
# Check channel 170 for sigma
# (170, 3, 140, 1.1, 100)
# Check channel 171 for sigma
# (171, 1, 140, 1.1, 100)
# Check channel 174 for sigma
# (174, 3, 140, 1.1, 100)
# Check channel 175 for sigma
# (175, 1, 140, 1.1, 100)
# Check channel 176 for sigma
# (176, 3, 140, 1.1, 100)
# Check channel 178 for sigma
# (178, 1, 140, 1.1, 100)
# Check channel 180 for sigma
# (180, 4, 140, 1.1, 100)
# Check channel 181 for sigma
# (181, 1, 140, 1.1, 100)
# Check channel 182 for sigma
# (182, 1, 140, 1.1, 100)
# Check channel 184 for sigma
# (184, 1, 140, 1.1, 100)
# Check channel 185 for sigma
# (185, 3, 140, 1.1, 100)
# Check channel 186 for sigma
# (186, 1, 140, 1.1, 100)
# Check channel 187 for sigma
# (187, 1, 140, 1.1, 100)
# Check channel 189 for sigma
# (189, 1, 140, 1.1, 100)
# Check channel 191 for sigma
# (191, 2, 140, 1.1, 100)
# Check channel 192 for sigma
# (192, 5, 140, 1.1, 100)
# Check channel 194 for sigma
# (194, 1, 140, 1.1, 100)
# Check channel 195 for sigma
# (195, 2, 140, 1.1, 100)
# Check channel 200 for sigma
# (200, 1, 140, 1.1, 100)
# Check channel 202 for sigma
# (202, 1, 140, 1.1, 100)
# Check channel 203 for sigma
# (203, 3, 140, 1.1, 100)
# Check channel 204 for sigma
# (204, 1, 140, 1.1, 100)
# Check channel 205 for sigma
# (205, 1, 140, 1.1, 100)
# Check channel 208 for sigma
# (208, 1, 140, 1.1, 100)
# Check channel 209 for sigma
# (209, 1, 140, 1.1, 100)
# Check channel 210 for sigma
# (210, 4, 140, 1.1, 100)
# Check channel 211 for sigma
# (211, 1, 140, 1.1, 100)
# Check channel 212 for sigma
# (212, 4, 140, 1.1, 100)
# Check channel 213 for sigma
# (213, 1, 140, 1.1, 100)
# Check channel 214 for sigma
# (214, 1, 140, 1.1, 100)
# Check channel 215 for sigma
# (215, 1, 140, 1.1, 100)
# Histogram 216 is empty (has 2.0 entries).
# Check channel 217 for sigma
# (217, 1, 140, 1.1, 100)
# Check channel 219 for sigma
# (219, 4, 140, 1.1, 100)
# Check channel 220 for sigma
# (220, 1, 140, 1.1, 100)
# Check channel 221 for sigma
# (221, 1, 140, 1.1, 100)
# Check channel 222 for sigma
# (222, 1, 140, 1.1, 100)
# Check channel 223 for sigma
# (223, 4, 140, 1.1, 100)
# Check channel 225 for sigma
# (225, 1, 140, 1.1, 100)
# Check channel 228 for sigma
# (228, 3, 140, 1.1, 100)
# Check channel 230 for sigma
# (230, 4, 140, 1.1, 100)
# Check channel 231 for sigma
# (231, 1, 140, 1.1, 100)
# Check channel 232 for sigma
# (232, 1, 140, 1.1, 100)
# Check channel 233 for sigma
# (233, 3, 140, 1.1, 100)
# Check channel 234 for sigma
# (234, 2, 140, 1.1, 100)
# Check channel 235 for sigma
# (235, 3, 140, 1.1, 100)
# Check channel 236 for sigma
# (236, 6, 140, 1.1, 100)
# Check channel 237 for sigma
# (237, 1, 140, 1.1, 100)
# Check channel 238 for sigma
# (238, 2, 140, 1.1, 100)
# Check channel 239 for sigma
# (239, 6, 140, 1.1, 100)
# Check channel 240 for sigma
# (240, 4, 140, 1.1, 100)
# Check channel 242 for sigma
# (242, 1, 140, 1.1, 100)
# Check channel 243 for sigma
# (243, 4, 140, 1.1, 100)
# Check channel 244 for sigma
# (244, 4, 140, 1.1, 100)
# Check channel 245 for sigma
# (245, 6, 140, 1.1, 100)
# Check channel 248 for sigma
# (248, 3, 140, 1.1, 100)
# Check channel 251 for sigma
# (251, 2, 140, 1.1, 100)
# Check channel 252 for sigma
# (252, 10, 140, 1.1, 100)
# Check channel 253 for sigma
# (253, 9, 140, 1.1, 100)
# Check channel 254 for sigma
# (254, 1, 140, 1.1, 100)
# Check channel 255 for sigma
# (255, 3, 140, 1.1, 100)
# Check channel 256 for sigma
# (256, 8, 140, 1.1, 100)
# Check channel 257 for sigma
# (257, 4, 140, 1.1, 100)
# Check channel 259 for sigma
# (259, 6, 140, 1.1, 100)
# Check channel 260 for sigma
# (260, 3, 140, 1.1, 100)
# Check channel 261 for sigma
# (261, 3, 140, 1.1, 100)
# Check channel 262 for sigma
# (262, 2, 140, 1.1, 100)
# Check channel 263 for sigma
# (263, 3, 140, 1.1, 100)
# Check channel 264 for sigma
# (264, 3, 140, 1.1, 100)
# Check channel 266 for sigma
# (266, 5, 140, 1.1, 100)
# Check channel 268 for sigma
# (268, 1, 140, 1.1, 100)
# Check channel 269 for sigma
# (269, 1, 140, 1.1, 100)
# Check channel 270 for sigma
# (270, 6, 140, 1.1, 100)
# Check channel 271 for sigma
# (271, 1, 140, 1.1, 100)
# Check channel 272 for sigma
# (272, 1, 140, 1.1, 100)
# Histogram 273 is empty (has 1.0 entries).
# Check channel 274 for sigma
# (274, 2, 140, 1.1, 100)
# Check channel 275 for sigma
# (275, 1, 140, 1.1, 100)
# Check channel 276 for sigma
# (276, 8, 140, 1.1, 100)
# Check channel 277 for sigma
# (277, 2, 140, 1.1, 100)
# Check channel 278 for sigma
# (278, 1, 140, 1.1, 100)
# Check channel 279 for sigma
# (279, 1, 140, 1.1, 100)
# Check channel 280 for sigma
# (280, 3, 140, 1.1, 100)
# Check channel 283 for sigma
# (283, 5, 140, 1.1, 100)
# Check channel 284 for sigma
# (284, 7, 140, 1.1, 100)
# Check channel 285 for sigma
# (285, 1, 140, 1.1, 100)
# Check channel 286 for sigma
# (286, 4, 140, 1.1, 100)
# Check channel 287 for sigma
# (287, 1, 140, 1.1, 100)
# Check channel 288 for sigma
# (288, 1, 140, 1.1, 100)
# Check channel 289 for sigma
# (289, 9, 140, 1.1, 100)
# Check channel 290 for sigma
# (290, 3, 140, 1.1, 100)
# Check channel 291 for sigma
# (291, 4, 140, 1.1, 100)
# Check channel 292 for sigma
# (292, 3, 140, 1.1, 100)
# Check channel 293 for sigma
# (293, 5, 140, 1.1, 100)
# Check channel 297 for sigma
# (297, 2, 140, 1.1, 100)
# Check channel 298 for sigma
# (298, 2, 140, 1.1, 100)
# Check channel 299 for sigma
# (299, 2, 140, 1.1, 100)
# Check channel 300 for sigma
# (300, 2, 140, 1.1, 100)
# Check channel 301 for sigma
# (301, 1, 140, 1.1, 100)
# Check channel 302 for sigma
# (302, 2, 140, 1.1, 100)
# Check channel 304 for sigma
# (304, 1, 140, 1.1, 100)
# Check channel 305 for sigma
# (305, 3, 140, 1.1, 100)
# Check channel 306 for sigma
# (306, 9, 140, 1.1, 100)
# Check channel 307 for sigma
# (307, 8, 140, 1.1, 100)
# Check channel 308 for sigma
# (308, 8, 140, 1.1, 100)
# Check channel 309 for sigma
# (309, 2, 140, 1.1, 100)
# Check channel 310 for sigma
# (310, 1, 140, 1.1, 100)
# Check channel 312 for sigma
# (312, 3, 140, 1.1, 100)
# Check channel 314 for sigma
# (314, 7, 140, 1.1, 100)
# Check channel 316 for sigma
# (316, 1, 140, 1.1, 100)
# Check channel 319 for sigma
# (319, 1, 140, 1.1, 100)
# Check channel 320 for sigma
# (320, 9, 140, 1.1, 100)
# Check channel 321 for sigma
# (321, 3, 140, 1.1, 100)
# Check channel 322 for sigma
# (322, 1, 140, 1.1, 100)
# Check channel 324 for sigma
# (324, 1, 140, 1.1, 100)
# Check channel 325 for sigma
# (325, 4, 140, 1.1, 100)
# Check channel 326 for sigma
# (326, 7, 140, 1.1, 100)
# Histogram 327 is empty (has 2.0 entries).
# Check channel 331 for sigma
# (331, 3, 140, 1.1, 100)
# Check channel 334 for sigma
# (334, 1, 140, 1.1, 100)
# Check channel 336 for sigma
# (336, 3, 140, 1.1, 100)
# Check channel 337 for sigma
# (337, 5, 140, 1.1, 100)
# Check channel 339 for sigma
# (339, 5, 140, 1.1, 100)
# Check channel 340 for sigma
# (340, 1, 140, 1.1, 100)
# Check channel 341 for sigma
# (341, 2, 140, 1.1, 100)
# Check channel 342 for sigma
# (342, 10, 140, 1.1, 100)
# Check channel 343 for sigma
# (343, 2, 140, 1.1, 100)
# Check channel 344 for sigma
# (344, 3, 140, 1.1, 100)
# Check channel 345 for sigma
# (345, 3, 140, 1.1, 100)
# Check channel 346 for sigma
# (346, 6, 140, 1.1, 100)
# Check channel 347 for sigma
# (347, 1, 140, 1.1, 100)
# Check channel 348 for sigma
# (348, 1, 140, 1.1, 100)
# Check channel 349 for sigma
# (349, 6, 140, 1.1, 100)
# Check channel 350 for sigma
# (350, 9, 140, 1.1, 100)
# Check channel 351 for sigma
# (351, 4, 140, 1.1, 100)
# Check channel 352 for sigma
# (352, 1, 140, 1.1, 100)
# Check channel 353 for sigma
# (353, 5, 140, 1.1, 100)
# Check channel 354 for sigma
# (354, 2, 140, 1.1, 100)
# Check channel 355 for sigma
# (355, 11, 140, 1.1, 100)
# Check channel 357 for sigma
# (357, 5, 140, 1.1, 100)
# Check channel 358 for sigma
# (358, 10, 140, 1.1, 100)
# Check channel 359 for sigma
# (359, 8, 140, 1.1, 100)
# Check channel 360 for sigma
# (360, 1, 140, 1.1, 100)
# Check channel 361 for sigma
# (361, 13, 140, 1.1, 100)
# Check channel 362 for sigma
# (362, 1, 140, 1.1, 100)
# Check channel 363 for sigma
# (363, 2, 140, 1.1, 100)
# Check channel 365 for sigma
# (365, 4, 140, 1.1, 100)
# Check channel 366 for sigma
# (366, 1, 140, 1.1, 100)
# Check channel 367 for sigma
# (367, 3, 140, 1.1, 100)

# %% [markdown]
# Finding how much each peak is off from zero, and setting it back to zero:

# %%
bins = 1300
ROOT.enableJSVis()
tagger_calib = ROOT.TFile("tagger_calib.root","RECREATE")

histos_calib = [None]*taggerChannels
for i in range(taggerChannels):
    histos_calib[i] = Hist(bins,-500,800)

for i in range(taggerChannels):
    print(i, peak[i])
    if (peak[i]!=None):
        histos_calib[i] = Hist(bins,int(-500-peak[i]),int(800-peak[i]))
        for j in range(bins):
            histos_calib[i].SetBinContent(j,histos[i].GetBinContent(j))
     
    histos_calib[i].SetTitle("Channel "+str(i))      
    histos_calib[i].Draw() 
    
    histos_calib[i].Write("tagger_calib")
# Out:
# (0, 141.4042947270836)
# (1, 142.28949720528084)
# (2, 141.94182736480454)
# (3, 141.3305394562416)
# (4, 143.88012519836644)
# (5, 142.23938725218036)
# (6, 142.38047226689775)
# (7, 141.87718539307477)
# (8, 141.4617262172606)
# (9, 142.55642898602932)
# (10, 141.54571877439778)
# (11, 141.00716798257548)
# (12, 141.15864868655183)
# (13, 141.52354248405885)
# (14, 142.15461158336666)
# (15, 142.21064023193884)
# (16, 143.7957869262562)
# (17, 144.400522965579)
# (18, 143.29396557574674)
# (19, 143.1916967315927)
# (20, 143.15872256395076)
# (21, 143.59149619792203)
# (22, 143.910891686622)
# (23, 143.88712718343433)
# (24, 140.8918319382066)
# (25, 134.46077710350292)
# (26, 140.44715947976331)
# (27, 140.38135524366072)
# (28, 140.95142945661215)
# (29, 141.08628247401242)
# (30, 141.7166733939442)
# (31, 142.8923939065237)
# (32, 140.2949200298721)
# (33, 141.194192692386)
# (34, 139.7783838412325)
# (35, 139.8789342011421)
# (36, 139.97978754273674)
# (37, 140.4580655040984)
# (38, 143.87821333210061)
# (39, 140.60819683363047)
# (40, 141.43044373584914)
# (41, 141.90511438604423)
# (42, 141.76606149923003)
# (43, 140.89730133242352)
# (44, 142.06236865275068)
# (45, 141.95539456033035)
# (46, 142.37562333996067)
# (47, 142.49876145419304)
# (48, 138.7819209570611)
# (49, 139.74398238956988)
# (50, 139.28930123028513)
# (51, 139.13055636249143)
# (52, 137.94237312087444)
# (53, 138.3766654860307)
# (54, 138.86243368334436)
# (55, 139.0113977733828)
# (56, 138.54095029075862)
# (57, 138.83090065703684)
# (58, 139.3545509568351)
# (59, 138.0768259101816)
# (60, 138.31906365212106)
# (61, 138.96159119661152)
# (62, 139.09450633611885)
# (63, 138.99943182159248)
# (64, 139.4622979610554)
# (65, 140.24096174935474)
# (66, 140.021914858856)
# (67, 139.73331252336277)
# (68, 138.90350530928413)
# (69, 140.18076168013403)
# (70, 140.3498437581802)
# (71, 140.42836813453948)
# (72, 136.43109134956887)
# (73, 137.3005592431167)
# (74, 137.02855282988838)
# (75, 136.67527191399878)
# (76, 137.19529940988807)
# (77, 137.30674216608725)
# (78, 137.44085824631787)
# (79, 136.98807294419206)
# (80, 135.7651426224944)
# (81, 137.41295385763925)
# (82, 136.49181325441825)
# (83, 135.95090761793378)
# (84, 136.2175036353374)
# (85, 137.15777034229316)
# (86, 137.5678565622795)
# (87, 136.71968240159924)
# (88, 138.08747225059867)
# (89, 139.97648289907326)
# (90, 138.15534078928292)
# (91, 138.31720308737926)
# (92, 138.57155104405962)
# (93, 139.59474349116147)
# (94, 139.02142739342653)
# (95, 139.30071215902944)
# (96, 134.8803036458997)
# (97, 135.6298106844685)
# (98, 134.7464033737676)
# (99, 134.6025359015411)
# (100, 134.43377886339766)
# (101, 135.10757138846924)
# (102, 135.26972340793623)
# (103, 135.41344587666947)
# (104, 134.4266127196915)
# (105, 135.22019715884366)
# (106, 134.7308753601673)
# (107, 134.70973539434195)
# (108, 134.19951564698107)
# (109, 135.11380837216706)
# (110, 135.09318550098362)
# (111, 135.02917371677432)
# (112, 136.12404848460844)
# (113, 136.61709874391337)
# (114, 136.33651881724913)
# (115, 136.17543939694121)
# (116, 136.08917204906163)
# (117, 136.90748731627744)
# (118, 136.95124404416077)
# (119, 137.40920976306597)
# (120, 133.82564066912934)
# (121, 136.0760218861654)
# (122, 133.8181007160623)
# (123, 133.67646094287835)
# (124, 133.77544318044028)
# (125, 134.3415838831192)
# (126, 134.49143692277187)
# (127, 134.30347120044)
# (128, 132.69075307752408)
# (129, 134.29521854104513)
# (130, 133.16818961104892)
# (131, 133.05171510524616)
# (132, 133.14225951912445)
# (133, 134.13490913547176)
# (134, 133.87407852635897)
# (135, 134.0317704434561)
# (136, 134.85304982129784)
# (137, 135.9100948792213)
# (138, 134.6272675659688)
# (139, 134.82326809124922)
# (140, 135.23821392613425)
# (141, 135.85412156752642)
# (142, 135.73441594164294)
# (143, 135.91729410603307)
# (144, 131.41760012349044)
# (145, 133.0602712106792)
# (146, 131.325583967605)
# (147, 131.7146608032077)
# (148, 131.59283298823715)
# (149, 132.02703082842686)
# (150, 131.7668718860128)
# (151, 131.99638659928323)
# (152, 132.1373498965745)
# (153, 132.93501607311873)
# (154, 131.9613743581763)
# (155, 132.0018809352202)
# (156, 131.4095530963772)
# (157, 131.8830427523429)
# (158, 132.05787517172703)
# (159, 132.68002627109698)
# (160, 134.0470566967984)
# (161, 134.48855397366924)
# (162, 133.62027196347907)
# (163, 133.7622377331607)
# (164, 132.80705597938254)
# (165, 133.56773293970548)
# (166, 133.94173603932865)
# (167, 133.48734187748997)
# (168, 137.6585139301022)
# (169, 130.40382404862933)
# (170, 130.7717464870885)
# (171, 130.06086629447546)
# (172, 131.37284622494997)
# (173, 131.64934136427541)
# (174, 131.79351388398717)
# (175, 131.66423942423543)
# (176, 130.9881703864789)
# (177, 131.32107657419817)
# (178, 129.91212412269564)
# (179, 130.18423065814036)
# (180, 130.87792534507133)
# (181, 130.94444733586877)
# (182, 131.49789352889167)
# (183, 131.59519786983105)
# (184, 132.25584260331186)
# (185, 133.1711664176721)
# (186, 131.83015942729338)
# (187, 132.28611558089932)
# (188, 132.26554375254437)
# (189, 133.11914012668657)
# (190, 133.69450891970675)
# (191, 132.77016378533412)
# (192, 129.03921105472804)
# (193, 129.0895576966337)
# (194, 128.70666672327675)
# (195, 128.88781980113515)
# (196, 129.44442929184837)
# (197, 129.64489372798337)
# (198, 129.91786272103786)
# (199, 129.7884503299665)
# (200, 129.249059675821)
# (201, 129.939823856365)
# (202, 128.88745106941766)
# (203, 129.17619080915458)
# (204, 129.00382530349864)
# (205, 129.1824299236195)
# (206, 129.7002534559592)
# (207, 129.57819511744592)
# (208, 130.76603100774116)
# (209, 130.44216790413856)
# (210, 130.4283756188984)
# (211, 130.4768036556891)
# (212, 130.72339381071458)
# (213, 130.77798911381137)
# (214, 131.36498437605013)
# (215, 131.34877586915886)
# (216, None)
# (217, 128.04691712530985)
# (218, 128.5657556923264)
# (219, 129.25303965843506)
# (220, 128.7184273389344)
# (221, 129.1752555633982)
# (222, 129.07981192707183)
# (223, 129.73644300351958)
# (224, 128.17005124238148)
# (225, 128.3699779460806)
# (226, 127.22084274778705)
# (227, 128.98428784517452)
# (228, 128.78503269020246)
# (229, 128.59101849680195)
# (230, 129.28483583446854)
# (231, 129.23877339432195)
# (232, 128.97959513677802)
# (233, 129.50469753187696)
# (234, 129.11284762167637)
# (235, 129.00513115744363)
# (236, 130.43430310255573)
# (237, 130.61074551655005)
# (238, 130.47748121321345)
# (239, 130.97334044481423)
# (240, 127.12485645042798)
# (241, 128.0692456696609)
# (242, 126.95679275957274)
# (243, 127.4025614820042)
# (244, 126.61365657225078)
# (245, 127.62912799755001)
# (246, 127.6398384413107)
# (247, 127.62256062816421)
# (248, 126.44343792484615)
# (249, 126.78749453811886)
# (250, 126.89291853257988)
# (251, 126.80012212555222)
# (252, 127.29117912854136)
# (253, 127.65429116697379)
# (254, 128.47868942681413)
# (255, 127.81682553259824)
# (256, 129.47915309244524)
# (257, 129.29651141069448)
# (258, 129.3266710818193)
# (259, 129.1220669629436)
# (260, 128.6192170922113)
# (261, 128.7654448503702)
# (262, 128.6198323913336)
# (263, 130.01327882843165)
# (264, 141.0490236545773)
# (265, 137.16327434693468)
# (266, 136.18758610329)
# (267, 137.1451617328063)
# (268, 126.31345817553989)
# (269, 126.87850146265833)
# (270, 126.46642952497251)
# (271, 127.7912336357198)
# (272, 126.48256714077007)
# (273, None)
# (274, 126.03991205096233)
# (275, 125.88014064187603)
# (276, 125.81660897821102)
# (277, 126.55617459680575)
# (278, 127.21005912696091)
# (279, 126.91766244145181)
# (280, 128.45823163312028)
# (281, 128.628356920738)
# (282, 127.5253797106496)
# (283, 127.68877417827974)
# (284, 128.4092576943517)
# (285, 128.71641174438446)
# (286, 128.45506713826046)
# (287, 136.9749122953718)
# (288, 125.0761389364153)
# (289, 126.42736660306286)
# (290, 125.58722755544667)
# (291, 125.83625009517284)
# (292, 125.68198470284602)
# (293, 125.41734713449327)
# (294, 126.22096419053047)
# (295, 126.03540316883934)
# (296, 125.52065360595152)
# (297, 125.76496474607652)
# (298, 125.45003254975909)
# (299, 125.59389118739405)
# (300, 125.56820812817683)
# (301, 126.11237382901194)
# (302, 126.356435231315)
# (303, 125.78319817716768)
# (304, 127.33052583634831)
# (305, 127.60020030926312)
# (306, 126.92840410229027)
# (307, 127.46850340280393)
# (308, 127.32006576231348)
# (309, 128.02402153652434)
# (310, 128.26719240873726)
# (311, 127.9549948901921)
# (312, 143.8430670884989)
# (313, 135.50112783298434)
# (314, 142.15671280488812)
# (315, 159.2366964314417)
# (316, 157.00000332700745)
# (317, 136.0244708717012)
# (318, 135.82623082043852)
# (319, 135.9437530777356)
# (320, 135.81484061450195)
# (321, 135.8148538778533)
# (322, 134.4607214416558)
# (323, 134.61328917025455)
# (324, 125.45715343889066)
# (325, 125.40201122832875)
# (326, 125.77595313052397)
# (327, None)
# (328, 125.88803818645857)
# (329, 133.49225024160583)
# (330, 133.5222188760359)
# (331, 146.55125840507054)
# (332, 142.95963093383241)
# (333, 143.71772485255036)
# (334, 143.05834566063737)
# (335, 143.00430694027216)
# (336, 142.98503700980865)
# (337, 144.2357253720708)
# (338, 144.23762511179663)
# (339, 143.6794670406775)
# (340, 143.6973319612062)
# (341, 144.6753049267239)
# (342, 143.8115102282887)
# (343, 144.15749310544183)
# (344, 142.73392111003943)
# (345, 144.27723009751145)
# (346, 143.47408867520224)
# (347, 143.60969651682365)
# (348, 145.12100746210194)
# (349, 146.13989228732495)
# (350, 145.74499019880272)
# (351, 145.97903315331703)
# (352, 144.8836636304283)
# (353, 146.03778855332246)
# (354, 145.04649040800098)
# (355, 145.34375563623513)
# (356, 144.6032955369038)
# (357, 145.92570987187887)
# (358, 145.17858719244023)
# (359, 145.64072668023275)
# (360, 142.23190934109644)
# (361, 143.61377268683137)
# (362, 143.38021878753727)
# (363, 143.03267335511663)
# (364, 142.73433358522513)
# (365, 143.85387624109123)
# (366, 143.227516458119)
# (367, 143.47019667920063)

# %% [markdown]
# Next, we must import the json file, change the channel offset values, and then save the array again as a new json file. Note that the empty histograms write a value of 'None' to the json file for their offsets.

# %%
calibData = json.load(open('taggerNewer.json'), object_pairs_hook=OrderedDict)     # load the tagger calibration data and keep its original ordering

i = 0                                   # starting at channel 0
for chan in calibData['channels']:      # for each of the tagger channels
    chan['offset'][0] = peak[i]         # change the offset value to the one found in our earlier fit for that channel
    i+=1                                # move on to the next channel

json.dump(calibData, open('taggerWithOffsets.json', 'w'), indent = 2)              # write the changed data to a new json file
